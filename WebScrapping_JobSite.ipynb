# %%
from bs4 import BeautifulSoup

# %%
import requests

# %% [markdown]
# **Search the web page that we need and copy the url.**

# %%
html_text=requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
print(html_text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <head>
#
#
#
# <script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"1834934118",accountID:"3252369",trustKey:"2223361",xpid:"VwQCU1VVARABXFJQAQgFUlIE",licenseKey:"NRJS-155b87767dc9cc0075a",applicationID:"1832692465"};;/*! For license information please see nr-loader-spa-1.243.1.min.js.LICENSE.txt */
# ...

# %%
soup=BeautifulSoup(html_text,'lxml')

# %% [markdown]
# ### If we only want one job that appear on the first page

# %% [markdown]
# **Select one text>right click>inspect>we'll get the html commands>from 'li'(list) copy the command>paste**

# %%
job=soup.find('li',class_ = 'clearfix job-bx wht-shd-bx')
print(job)
# Out:
# <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/python-developer-connecting-2-work-thiruvananthapuram-5-to-10-yrs-jobid-Tebue__SLASH__8iTzVzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69009460','python  ,  storage  ,  django  ,  testing tools  ,  debugging','Thiruvananthapuram','5 - 10','IT Software : Software Products &amp; Services','1' )" target="_blank">
# <strong class="blkclor">Python</strong> Developer</a> </h2>
# <h3 class="joblist-comp-name">
#     CONNECTING 2 WORK
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>5 - 10 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Thiruvananthapuram">Thiruvananthapuram</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# ...

# %% [markdown]
# **If we want to search the company name, Select the text>right click>inspect>html commands>copy html command**

# %%
company_name=job.find('h3',class_ ='joblist-comp-name').text

# %%
print(company_name)
# Out:
#     CONNECTING 2 WORK

# %% [markdown]
# **If we want to replace the white space**

# %%
company_name=job.find('h3',class_ ='joblist-comp-name').text.replace(' ','')
print(company_name)
# Out:
# CONNECTING2WORK

# %% [markdown]
# **Checking the skills,  Select the text>right click>inspect>html commands>copy html command**

# %%
skills=job.find('span',class_ = 'srp-skills').text
print(skills)
# Out:
# python  ,  storage  ,  django  ,  testing tools  ,  debugging

# %%
#replacing white space
skills=job.find('span',class_ = 'srp-skills').text.replace(' ','')
print(skills)
# Out:
# python,storage,django,testingtools,debugging

# %% [markdown]
# **If we want to get a nice information**

# %%
print(f''' 
Company Name:{company_name}
Required Skills:{skills}
''')
# Out:
#
# Company Name:
# CONNECTING2WORK
#
#
# Required Skills:
# python,storage,django,testingtools,debugging

# %% [markdown]
# **If we want to check the date of job post, Select the text>right click>inspect>html commands>copy html command**

# %%
published_date=job.find('span',class_ = 'sim-posted').span.text
print(published_date)
# Out:
# Posted 2 days ago

# %% [markdown]
# ### If we need all the jobs that appears on the first page

# %%
jobs=soup.find_all('li',class_ = 'clearfix job-bx wht-shd-bx')

# %%
for job in jobs:
    company_name=job.find('h3',class_ ='joblist-comp-name').text.replace(' ','')
    skills=job.find('span',class_ = 'srp-skills').text.replace(' ','')
    published_date=job.find('span',class_ = 'sim-posted').span.text
print(f''' 
Company Name:{company_name}
Required Skills:{skills}
''')
print('')
# Out:
#
# Company Name:
# SourcedeskGlobalPrivateLimited
#
#
# Required Skills:
#
# html5,storage,python,javascript,django,infrastructure

# %% [markdown]
# **Taking the jobs that are posted 'few' days ago by rearranging the 'published_date' position.**

# %%
for job in jobs:
    published_date=job.find('span',class_ = 'sim-posted').span.text
    if 'few' in published_date:
        company_name=job.find('h3',class_ ='joblist-comp-name').text.replace(' ','')
        skills=job.find('span',class_ = 'srp-skills').text.replace(' ','')
    
    
        print(f''' 
       Company Name:{company_name}
       Required Skills:{skills}
       ''')
        print('')
# Out:
#
#        Company Name:
# IvanInfotechPvt.Ltd.
#
#
#        Required Skills:
#
# rest,python,security,debugging
#
#
#
#
#
#        Company Name:
# eastindiasecuritiesltd.
#
#
#        Required Skills:
# python,hadoop,machinelearning
#
#
#
#
#
#        Company Name:
# glanmanagementconsultancypvt.ltd.
#
#
#        Required Skills:
# python,rdbms,mysql,cloudcomputing,docker,sql
#
#
#
#
#
#        Company Name:
# WingGlobalITServices
#
#
#        Required Skills:
#
# springboot,python,java,django,jpa,hibernate
#
#
#
#
#
#        Company Name:
# arttechnologyandsoftwareindiapvtltd
#
#
#        Required Skills:
#
# rest,python,database,django,api
#
#
#
#
#
#        Company Name:
# youngmindstechnologysolutionspvtltd
#
#
#        Required Skills:
# python,html5,storage,javascript,security,django
#
#
#
#
#
#        Company Name:
# DREAMAJAXTECHNOLOGIES
#
#
#        Required Skills:
# python,django,api,sql,nosql
#
#
#
#
#
#        Company Name:
# day1technologies
#
#
# ...

# %% [markdown]
# **Displaying in a good order**

# %%
for job in jobs:
    published_date=job.find('span',class_ = 'sim-posted').span.text
    if 'few' in published_date:
        company_name=job.find('h3',class_ ='joblist-comp-name').text.replace(' ','')
        skills=job.find('span',class_ = 'srp-skills').text.replace(' ','')
        print(f"Company Name: {company_name.strip()}")
        print(f"Required Skills: {skills.strip()}")
        
        print('')
# Out:
# Company Name: IvanInfotechPvt.Ltd.
# Required Skills: rest,python,security,debugging
#
# Company Name: eastindiasecuritiesltd.
# Required Skills: python,hadoop,machinelearning
#
# Company Name: glanmanagementconsultancypvt.ltd.
# Required Skills: python,rdbms,mysql,cloudcomputing,docker,sql
#
# Company Name: WingGlobalITServices
# Required Skills: springboot,python,java,django,jpa,hibernate
#
# Company Name: arttechnologyandsoftwareindiapvtltd
# Required Skills: rest,python,database,django,api
#
# Company Name: youngmindstechnologysolutionspvtltd
# Required Skills: python,html5,storage,javascript,security,django
#
# Company Name: DREAMAJAXTECHNOLOGIES
# Required Skills: python,django,api,sql,nosql
#
# Company Name: day1technologies
# Required Skills: rest,python,django,git,postgresql,sql,docker
#
# Company Name: xoniertechnologiespvtltd
# Required Skills: python,django,testingtools,debugging,storage
#
# Company Name: destinyhrgroupservices
# ...

# %% [markdown]
# **Displaying along with the job links**

# %%
for job in jobs:
    published_date=job.find('span',class_ = 'sim-posted').span.text
    if 'few' in published_date:
        company_name=job.find('h3',class_ ='joblist-comp-name').text.replace(' ','')
        skills=job.find('span',class_ = 'srp-skills').text.replace(' ','')
        more_info=job.header.a['href']
        print(f"Company Name: {company_name.strip()}")
        print(f"Required Skills: {skills.strip()}")
        print(f"Link to Apply: {more_info}")
        print('')
# Out:
# Company Name: IvanInfotechPvt.Ltd.
# Required Skills: rest,python,security,debugging
# Link to Apply: https://www.timesjobs.com/job-detail/python-developer-ivan-infotech-pvt-ltd-kolkata-2-to-5-yrs-jobid-1h6sLaqbaBZzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: eastindiasecuritiesltd.
# Required Skills: python,hadoop,machinelearning
# Link to Apply: https://www.timesjobs.com/job-detail/python-engineer-east-india-securities-ltd-kolkata-2-to-5-yrs-jobid-KEkE19WqPbFzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: glanmanagementconsultancypvt.ltd.
# Required Skills: python,rdbms,mysql,cloudcomputing,docker,sql
# Link to Apply: https://www.timesjobs.com/job-detail/python-developer-glan-management-consultancy-pvt-ltd-noida-greater-noida-5-to-8-yrs-jobid-2yjhPFea__SLASH__AJzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: WingGlobalITServices
# Required Skills: springboot,python,java,django,jpa,hibernate
# ...

# %% [markdown]
# ### Allowing the user to input their skills and find the job to apply

# %%
print('Put some skill that you are not familiar with')
unfamiliar_skill=input('>')
print(f'Filtering out {unfamiliar_skill}')

html_text=requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup=BeautifulSoup(html_text,'lxml')
jobs=soup.find_all('li',class_ = 'clearfix job-bx wht-shd-bx')
for job in jobs:
    published_date=job.find('span',class_ = 'sim-posted').span.text
    if 'few' in published_date:
        company_name=job.find('h3',class_ ='joblist-comp-name').text.replace(' ','')
        skills=job.find('span',class_ = 'srp-skills').text.replace(' ','')
        more_info=job.header.a['href']
        if unfamiliar_skill not in skills:
            print(f"Company Name: {company_name.strip()}")
            print(f"Required Skills: {skills.strip()}")
            print(f"Link to Apply: {more_info}")
            print('')
# Out:
# Put some skill that you are not familiar with
# >linux
# Filtering out linux
# Company Name: IvanInfotechPvt.Ltd.
# Required Skills: rest,python,security,debugging
# Link to Apply: https://www.timesjobs.com/job-detail/python-developer-ivan-infotech-pvt-ltd-kolkata-2-to-5-yrs-jobid-1h6sLaqbaBZzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: eastindiasecuritiesltd.
# Required Skills: python,hadoop,machinelearning
# Link to Apply: https://www.timesjobs.com/job-detail/python-engineer-east-india-securities-ltd-kolkata-2-to-5-yrs-jobid-KEkE19WqPbFzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: glanmanagementconsultancypvt.ltd.
# Required Skills: python,rdbms,mysql,cloudcomputing,docker,sql
# Link to Apply: https://www.timesjobs.com/job-detail/python-developer-glan-management-consultancy-pvt-ltd-noida-greater-noida-5-to-8-yrs-jobid-2yjhPFea__SLASH__AJzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: WingGlobalITServices
# Required Skills: springboot,python,java,django,jpa,hibernate
# ...

# %%
import time
print('Put some skill that you are not familiar with')
unfamiliar_skill=input('>')
print(f'Filtering out {unfamiliar_skill}')

def find_jobs():
    html_text=requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
    soup=BeautifulSoup(html_text,'lxml')
    jobs=soup.find_all('li',class_ = 'clearfix job-bx wht-shd-bx')
    for job in jobs:
        published_date=job.find('span',class_ = 'sim-posted').span.text
        if 'few' in published_date:
            company_name=job.find('h3',class_ ='joblist-comp-name').text.replace(' ','')
            skills=job.find('span',class_ = 'srp-skills').text.replace(' ','')
            more_info=job.header.a['href']
            if unfamiliar_skill not in skills:
                print(f"Company Name: {company_name.strip()}")
                print(f"Required Skills: {skills.strip()}")
                print(f"Link to Apply: {more_info}")
                print('')
              

if __name__=='__main__':
    while True:
        find_jobs()
        time_wait=10
        print(f"Waiting {time_wait} minutes...")
        time.sleep(time_wait*60)
# Out:
# Put some skill that you are not familiar with
# >django
# Filtering out django
# Company Name: IvanInfotechPvt.Ltd.
# Required Skills: rest,python,security,debugging
# Link to Apply: https://www.timesjobs.com/job-detail/python-developer-ivan-infotech-pvt-ltd-kolkata-2-to-5-yrs-jobid-1h6sLaqbaBZzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: eastindiasecuritiesltd.
# Required Skills: python,hadoop,machinelearning
# Link to Apply: https://www.timesjobs.com/job-detail/python-engineer-east-india-securities-ltd-kolkata-2-to-5-yrs-jobid-KEkE19WqPbFzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: glanmanagementconsultancypvt.ltd.
# Required Skills: python,rdbms,mysql,cloudcomputing,docker,sql
# Link to Apply: https://www.timesjobs.com/job-detail/python-developer-glan-management-consultancy-pvt-ltd-noida-greater-noida-5-to-8-yrs-jobid-2yjhPFea__SLASH__AJzpSvf__PLUS__uAgZw==&source=srp
#
# Waiting 10 minutes...
# Company Name: IvanInfotechPvt.Ltd.
# ...
